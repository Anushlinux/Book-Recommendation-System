# %%
import pandas as pd
import numpy as np

books = pd.read_csv('books.csv')
ratings = pd.read_csv('ratings.csv')
users = pd.read_csv('users.csv')
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_22620\569542028.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings_name = ratings.merge(books, on = "ISBN")

# %%
ratings_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
new_ratings = ratings_name.groupby("Book-Title")["Book-Rating"].mean().reset_index()
new_ratings.rename(columns = {"Book-Rating" : "Avg Ratings"}, inplace = True)

# %%
new_ratings
# Out:
#                                                Book-Title  Avg Ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
new_ratings
# Out:
#                                                Book-Title  Avg Ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
new_ratings.merge(new_ratings, ratings_name, on ="Book-Title")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22620\889399813.py in ?()
# ----> 1 new_ratings.merge(new_ratings, ratings_name, on ="Book-Title")
#
# c:\Users\anush\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9839         validate: str | None = None,
#    9840     ) -> DataFrame:
#    9841         from pandas.core.reshape.merge import merge
#    9842
# -> 9843         return merge(
#    9844             self,
#    9845             right,
#    9846             how=how,
#
# c:\Users\anush\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
# ...

# %%
popular_df = new_ratings.merge(ratings_name, on="Book-Title")

# %%
popular_df.reset_index()
# Out:
#            index                                         Book-Title  \
# 0              0   A Light in the Storm: The Civil War Diary of ...
# 1              1   A Light in the Storm: The Civil War Diary of ...
# 2              2   A Light in the Storm: The Civil War Diary of ...
# 3              3   A Light in the Storm: The Civil War Diary of ...
# 4              4                              Always Have Popsicles
# ...          ...                                                ...
# 1031131  1031131                              Ã?Â?stlich der Berge.
# 1031132  1031132                              Ã?Â?stlich der Berge.
# 1031133  1031133                              Ã?Â?stlich der Berge.
# 1031134  1031134                                  Ã?Â?thique en toc
# 1031135  1031135                                  Ã?Â?thique en toc
#
#          Avg Ratings  User-ID        ISBN  Book-Rating       Book-Author  \
# 0           2.250000    18995  0590567330            0       Karen Hesse
# ...

# %%
popular_df = new_ratings.merge(new_ratings, ratings_name, on = "Book-Title")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22620\256018585.py in ?()
# ----> 1 popular_df = new_ratings.merge(new_ratings, ratings_name, on = "Book-Title")
#
# c:\Users\anush\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9839         validate: str | None = None,
#    9840     ) -> DataFrame:
#    9841         from pandas.core.reshape.merge import merge
#    9842
# -> 9843         return merge(
#    9844             self,
#    9845             right,
#    9846             how=how,
#
# c:\Users\anush\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
# ...

# %%
import numpy as np
import pandas as pd

books = pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings.csv")

ratings_with_name = ratings.merge(books, on='ISBN')


num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating': 'num_ratings'}, inplace=True)


avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)


result_df = pd.merge(num_rating_df, avg_rating_df, on='Book-Title')


result_df
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_22620\1884039497.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books.csv")
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# ...

# %%
popular_df = result_df.merge(avg_rating_df, on = "Book-Title")

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating_x  avg_rating_y
# 0           2.250000      2.250000
# 1           0.000000      0.000000
# ...

# %%
top_rating = popular_df[popular_df['num_ratings'] >= 250]

# %%
top_rating.sort_values("avg_rating_x", ascending=False).head(50)
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
given_rating = top_rating.merge(books, on = "Book-Title").drop_duplicates("Book-Title").sort_values("num_ratings", ascending=False).sort_values("avg_rating_x", ascending=False)

# %%
given_rating.rename(columns={"avg_rating_x" : "avg_rating"}).drop(columns={"avg_rating_y"})
# Out:
#                                             Book-Title  num_ratings  \
# 226  Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 220       Harry Potter and the Goblet of Fire (Book 4)          387
# 229     Harry Potter and the Sorcerer's Stone (Book 1)          278
# 222  Harry Potter and the Order of the Phoenix (Boo...          347
# 217   Harry Potter and the Chamber of Secrets (Book 2)          556
# ..                                                 ...          ...
# 696       Vinegar Hill (Oprah's Book Club (Paperback))          265
# 722                                           Whispers          286
# 345                                  Presumed Innocent          294
# 258                                       Isle of Dogs          288
# 737                                        Wild Animus         2502
#
#      avg_rating        ISBN        Book-Author Year-Of-Publication  \
# 226    5.852804  0439136350      J. K. Rowling                1999
# ...
